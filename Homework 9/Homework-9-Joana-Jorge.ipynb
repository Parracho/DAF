# %% [markdown]
# 9ª aula: Metamateriais

# %% [markdown]
# **Exercício 1:**  Derive the previous equations and plot the effective mass as a function of  𝜔

# %%
k = 2;
m = 1;
m1 = 2;

# %%
w0 = Sqrt[2k/m];  (*fórmula retirada dos slides*)
w1 = Sqrt[2k/m1];

# %%
massaefetiva[w_]:=m(1-(w0^2/w^2));   (*Fórmula retirada dos slides*)
massaefetiva2[w_]:=m + ((m1*w1^2)/(w1^2-w^2));

# %%
Plot[massaefetiva[w],{w,-w0*Sqrt[(m+m1)/m],w0*Sqrt[(m+m1)/m]}]
# Out:
# -Graphics-

# %%
Plot[massaefetiva2[w],{w,-w0*Sqrt[(m+m1)/m],w0*Sqrt[(m+m1)/m]}]
# Out:
# -Graphics-

# %% [markdown]
# **Exercício 2:**  Follow ref. On the negative effective mass density in acoustic metamaterials and derive Eq. (6) and Eq. (10). Plot Fig.3 and Fig. 5.

# %% [markdown]
# Equação 6:

# %%
l= 4;
m1 = 1;
m2 = 9*m1;
k1 = 1;
k2 = 0.1*k1;
w = 23.73;   (*Frequência Angular, Hz*)
q = 1;   (*Número de Onda*)

# %%
equation[t_] = m1*m2*w^4 - (((m1+m2)*k2) + 2*m2*k1*(1-Cos[q*l]))w^2 + 2*k1*k2*(1-Cos[q*l]);
(*equação da dispersão*)
