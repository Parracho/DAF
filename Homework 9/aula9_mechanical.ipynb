# %% [markdown]
# # 9ª aula: Metamaterials

# %% [markdown]
# ## Bibliography
#
#
# 1. [Mechanical Metamaterials, Sebastian Huber, ETH Zurich](https://ethz.ch/content/dam/ethz/special-interest/phys/theoretical-physics/cmtm-dam/documents/mmm/SS2018/MMMF.pdf)
# 2. [On the negative effective mass density in acoustic metamaterials](https://www.sciencedirect.com/science/article/pii/S0020722508002279)
# 3.[Elastic metamaterials with local resonances: an overview](https://www.sciencedirect.com/science/article/pii/S2095034915301586?via%3Dihub)

# %% [markdown]
# __Load Latex Macros__  $
# \newcommand{\red}[1]{\textcolor{red}{#1}}
# \newcommand{\ket}[1]{\left\vert #1\right\rangle}
# \newcommand{\bra}[1]{\left\langle #1\right\vert}
# \newcommand{\ketbra}[1]{\ket{#1}\bra{#1}}
# \newcommand{\braket}[2]{\left\langle #1\left|\vphantom{{#1}{#2}}\right.#2\right\rangle}
# \newcommand{\sket}[1]{\vert #1 \rangle}     % small
# \newcommand{\sbra}[1]{\langle #1 \vert}     % small
# \newcommand{\sbraket}[2]{\langle #1 \vert #2\rangle}   % small
# \newcommand{\expect}[1]{\langle{#1}\rangle}
# \newcommand\avr[1]{\left\langle #1 \right\rangle}
# \newcommand{\abs}[1]{\left\vert #1 \right\vert}
# \newcommand{\avg}[1]{\langle #1 \rangle}          % small average
# \newcommand{\sca}[2]{\langle #1 \mid #2 \rangle}  % small scalar product
# \newcommand{\re}{\mathrm{Re}\,}
# \newcommand{\im}{\mathrm{Im}\,}
# \newcommand{\Tr}{\mathrm{Tr}\,}
# \newcommand{\diag}{\mathrm{diag}\,}
# \newcommand{\Pf}{\mathrm{Pf}}             % Pfaffian
# \newcommand{\nvec}[1]{{\mathbf {#1}}}
# \newcommand{\nvecgreek}[1]{\text{\boldmath{$ #1 $}}} % added by Andras
# \newcommand{\nvecr}{\nvec{r}}
# \newcommand{\nvecp}{\nvec{p}}
# \newcommand\nvect[1]{\mathbf{#1}}
# \newcommand\nab{\nvect{\nabla}}
# \newcommand{\nabr}{\nvect{\nabla}_\RR}
# \newcommand{\RR}{\nvect{R}}
# \newcommand{\hh}{\nvect{d}}
# \newcommand{\hhabs}{d}
# \newcommand{\kk}{\nvect{k}}
# \newcommand{\BZ}{\mathrm{BZ}}
# \newcommand{\AAA}{\nvect{A}}
# \newcommand{\BB}{\nvect{B}}
# \newcommand{\SSS}{\mathcal{S}}        % surface element
# \newcommand{\CC}{{\mathcal C}}        % curve
# \newcommand{\TTT}{\hat{\mathcal{T}}}  % time reversal
# \newcommand{\ssigma}{\boldsymbol{\sigma}}  % vector bold sigma
# \newcommand{\HH}{\hat{H}}               % Hamiltonian
# \newcommand{\Hbulk}{\hat{H}_\text{bulk}} % bulk H
# \newcommand{\HHbhz}{\hat{H}_\text{BHZ}}
# \newcommand{\HHtri}{\hat{H}_\text{TRI}}
# \newcommand{\Htri}{H_\text{TRI}}         % matrix of H_TRI
# \newcommand{\hsigma}{\hat{\sigma}}      % sigma operator
# \newcommand{\htau}{\hat{\tau}}          % tau operator
# \newcommand{\hs}{\hat{s}}               % spin operator
# \newcommand{\Inv}{\hat{\Pi}}            % inversion about the origin
# \newcommand{\Invi}{\hat{\pi}}           % inversion about the origin
# \newcommand{\PP}{\hat{P}}           % projector to occupied states
# \newcommand{\II}{\mathbb{I}}         % unit operator
# \newcommand{\jjj}{j}                 % Wannier state index
# \newcommand{\uu}{u}                  %  staggered onsite potential in QWZ
# \newcommand{\TRIM}{\text{TRIM}}
# \newcommand{\NF}{{N_F}}                 % number of filled bands, BHZ
# \newcommand{\Nbulk}{{N_\text{bulk}}}                 % number of filled bands, BHZ
# \newcommand{\wilsonv}{\underline{v}}    % eigenvector of Wilson loop
# %\newcommand{\MM}{\underline{\underline{M}}}   % overlap matrix
# %\newcommand{\WW}{\underline{\underline{W}}}   % Wilson loop matrix
# \newcommand{\MM}{{M}}   % overlap matrix
# \newcommand{\WW}{{W}}   % Wilson loop matrix
# \newcommand{\bea}{\begin{eqnarray*}}
# \newcommand{\eea}{\end{eqnarray*}}
# \newcommand{\bne}{\begin{equation*}}
# \newcommand{\ede}{\end{equation*}}
# %numbered equations:
# \newcommand{\bnen}{\begin{equation}}
# \newcommand{\eden}{\end{equation}}
# \newcommand{\bean}{\begin{eqnarray}}
# \newcommand{\eean}{\end{eqnarray}}
# \newcommand{\bnsn}{\begin{subequations}}
# \newcommand{\edsn}{\end{subequations}}
# \newcommand{\bna}{\begin{array}}
# \newcommand{\eda}{\end{array}}
# \newcommand{\bnm}{\begin{enumerate}}
# \newcommand{\edm}{\end{enumerate}}
# \newcommand{\uci}{m}             % unit cell index
# \newcommand{\vuci}{\nvect{\uci}} % unit cell index vector
# \newcommand{\nuc}{N}             % number of unit cells
# \newcommand{\idi}{\alpha}        % integral degree of freedom index
# \newcommand{\eii}{n}             % energy eigenstate index
# \newcommand{\chl}{l}             % channel label (for scattering, Landauer, etc)
# \newcommand{\rso}[1]{\hat{#1}} % real-space Hamiltonian and other real-space operators wear a hat
# \newcommand{\ido}[1]{\hat{#1}} % operator acting on internal degree of freedom, e.g., the momentum-space Hamiltonian, wears a hat
# \newcommand{\ground}{1}      % ground state of a two-level system
# \newcommand{\excited}{2}     % excited state of a two-level system
#  $

# %% [markdown]
# # Analogy between electric and mechanical oscillators
#
# Motivated by the mathematical analogy between acoustic and electromagnetic waves, some researchers have attempted to find the counterpart left-handed acoustic metamaterials. Basically, it is to find metamaterials that possess negative mass density and negative modulus [4–8]. However, in contrast to the natural negative electric permittivity, no natural material has been found to possess negative mass density or negative modulus. Ever since the investigation on locally resonant acoustic materials [9], some new developments have further been theoretically attempted and shown that metamaterials with certain manmade microstructures may exhibit negative mass/mass density if treated as a classical elastic solid.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Discrete mass-spring system
#
# ![image.png](attachment:image.png)
#
# The mechanism of negative effective mass can be discovered by the mass-spring structure shown in Fig. 1, where a hollow sphere of the weight $M_0$ connects a rigid sphere of weight m by two massless and elastic springs with equal spring cofficient G. In the time harmonic case, the equilibrium equation of the inner mass m results in
#
# $$
# \dfrac{x}{X}=\dfrac{\omega_1^2}{\omega_1^2-\omega^2}
# $$
#
# where x and X are respectively the displacement of the
# inner and outer mass, and $ω_1 = \sqrt{2G/m}$ is the resonant frequency. The composite hollow structure can be considered as an equivalent solid object and the effective mass $M_{eff}$ of the unit can be defined as the total momentum divided by the velocity of the outer mass
#
# $$
# M_{eff}=M_0+\dfrac{m \omega_1^2}{\omega_1^2-\omega^2}
# $$
#
# Due to the negative momentum of the inner mass
# overwhelming the system, the effective mass $M_{eff}$  takes
# negative values at frequencies ranging from $ω_0$ to $ω_0 \sqrt{(M_0 + m)/M_0}$. When the inner mass is fixed, effective dynamic mass  becomes
#
# $$
# M_{eff}=M_0 \left(1-\dfrac{\omega_0^2}{\omega^2} \right)
# $$
#
# where $ω_0 = \sqrt{2G/M_0}$.

# %% [markdown]
# __Exercise 1:__
#
# Derive the previous equations and plot the effective mass as a function of $\omega$

# %% [markdown]
# ## Negative effective mass in lattices
#
#
# The negative effective mass/mass density is the result of  modeling of acoustic metamaterials. In the present study, we consider a one-dimensional lattice consisting of lattice masses each of which contains an internal mass. This simple lattice system is employed to illustrate how the negative effective mass could occur and what effects it has on wave propagation in the lattice system.
#
# A one-dimensional model can be used to introduce the negative effective mass effect as shown in Figure below. If it is to be represented by a single mass, then the effective mass must be defined in order that the effective mass $m_{eff}$ would produce the same motion of $m_1$. In other words, the identity of the internal mass $m_2$ would be ignored and its effect would be absorbed by the introduction of an effective mass $m_{eff}$.
#
# ![image-7.png](attachment:image-7.png)
#
# The lattice system is constructed by connecting the unit cells of Figure above with linear springs. The unit-cells are placed periodically at a spacing of L. Harmonic wave propagation in the mass-in-mass lattice system is considered. The equations of motion for the j-th unit cell are
#
# $$
# m_1^{(j)} \dfrac{d^2 u_1^{(j)} }{dt^2}+k_1 (2 u_1^{(j)}-u_1^{(j-1)}-u_1^{(j+1)}) +k_2 (u_1^{(j)}-u_2^{(j)})=0
# $$
#
# $$
# m_2^{(j)} \dfrac{d^2 u_2^{(j)} }{dt^2}+k_2 (u_2^{(j)}-u_1^{(j)})=0
# $$

# %% [markdown]
# __Exercise 2:__
#
# Follow ref. [On the negative effective mass density in acoustic metamaterials](https://www.sciencedirect.com/science/article/pii/S0020722508002279) and derive Eq. (6) and Eq. (10).
# Plot Fig.3 and Fig. 5.

# %% [markdown]
# # Projects:
#
# * Do an analysis of the following system
#
# ![image.png](attachment:image.png)
#
# [Widening, Transition and Coalescence of Local Resonance Band Gaps in Multi-resonator Acoustic Metamaterials: From Unit Cells to Finite Chains](https://arxiv.org/abs/2107.08431v4)
